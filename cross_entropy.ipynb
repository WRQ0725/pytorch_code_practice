# %% [markdown]
# # 交叉熵验证法

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 预测值和真实值越接近，交叉熵代价函数的梯度越小，梯度下降更新率比较小；反之交叉熵函数梯度越大，更新快

# %% [markdown]
# ### 应用场景
# 分类任务的代价函数用交叉熵 </br>
# 回归问题的代价函数用二次代价函数
